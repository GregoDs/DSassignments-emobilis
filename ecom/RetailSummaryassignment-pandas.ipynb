# %%
#loading data

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
# Reading data

# %%
# check the tail of the dataset
# Out:
#   customer_id  tran_amount_2011  tran_amount_2012  tran_amount_2013  \
# 0      CS2945             153.0             516.0             173.0
# 1      CS4074             269.0             429.0             737.0
# 2      CS4798             153.0             536.0             414.0
# 3      CS4424             547.0             380.0             921.0
# 4      CS5057             290.0             235.0             509.0
#
#    tran_amount_2014  tran_amount_2015  transactions_2011  transactions_2012  \
# 0            1029.0              40.0                2.0                7.0
# 1            1027.0               NaN                3.0                6.0
# 2            1001.0              47.0                2.0                7.0
# 3             984.0             101.0                7.0                5.0
# 4             974.0               NaN                4.0                4.0
#
#    transactions_2013  transactions_2014  transactions_2015 First_Transaction  \
# ...

# %%
# shape & size of the dataset
# print(df.shape)
# Out:
# (6889, 13)
# 89557

# %%
# Finding the missing values in columns
# Out:
# customer_id              0
# tran_amount_2011       388
# tran_amount_2012        80
# tran_amount_2013        85
# tran_amount_2014        88
# tran_amount_2015      2664
# transactions_2011      388
# transactions_2012       80
# transactions_2013       85
# transactions_2014       88
# transactions_2015     2664
# First_Transaction        0
# Latest_Transaction       0
# dtype: int64

# %%
# filling missing values with 0
# make change permanent

# %%
# check the head
# Out:
#   customer_id  tran_amount_2011  tran_amount_2012  tran_amount_2013  \
# 0      CS2945             153.0             516.0             173.0
# 1      CS4074             269.0             429.0             737.0
# 2      CS4798             153.0             536.0             414.0
# 3      CS4424             547.0             380.0             921.0
# 4      CS5057             290.0             235.0             509.0
#
#    tran_amount_2014  tran_amount_2015  transactions_2011  transactions_2012  \
# 0            1029.0              40.0                2.0                7.0
# 1            1027.0               0.0                3.0                6.0
# 2            1001.0              47.0                2.0                7.0
# 3             984.0             101.0                7.0                5.0
# 4             974.0               0.0                4.0                4.0
#
#    transactions_2013  transactions_2014  transactions_2015 First_Transaction  \
# ...

# %%
# Total  amount & Tranx & ATV
df['Total Customer Spend'] = df.iloc[:,1:6].sum(axis=1)
df['Total Customer Tranx'] = df.iloc[:,6:-3].sum(axis=1)
df['Customer ATV'] = np.round(df['Total Customer Spend'].div(df['Total Customer Tranx']),2)
df.head()
# Out:
#   customer_id  tran_amount_2011  tran_amount_2012  tran_amount_2013  \
# 0      CS2945             153.0             516.0             173.0
# 1      CS4074             269.0             429.0             737.0
# 2      CS4798             153.0             536.0             414.0
# 3      CS4424             547.0             380.0             921.0
# 4      CS5057             290.0             235.0             509.0
#
#    tran_amount_2014  tran_amount_2015  transactions_2011  transactions_2012  \
# 0            1029.0              40.0                2.0                7.0
# 1            1027.0               0.0                3.0                6.0
# 2            1001.0              47.0                2.0                7.0
# 3             984.0             101.0                7.0                5.0
# 4             974.0               0.0                4.0                4.0
#
#    transactions_2013  transactions_2014  transactions_2015 First_Transaction  \
# ...

# %%
#customer with highest tranx value
# Out:
#   customer_id  tran_amount_2011  tran_amount_2012  tran_amount_2013  \
# 3      CS4424             547.0             380.0             921.0
#
#    tran_amount_2014  tran_amount_2015  transactions_2011  transactions_2012  \
# 3             984.0             101.0                7.0                5.0
#
#    transactions_2013  transactions_2014  transactions_2015 First_Transaction  \
# 3               13.0               13.0                1.0         25-May-11
#
#   Latest_Transaction  Total Customer Spend  Total Customer Tranx  Customer ATV
# 3          19-Jan-15                2933.0                  39.0         75.21

# %%
# slicing 
# Top 10 Customers in 2014 and 2015
Top_10_customers_tranx_2014_2015 = pd.DataFrame()
Top_10_customers_tranx_2014_2015[['customer_id_2014','tran_amount_2014']]= df[['customer_id','tran_amount_2014']].sort_values(by = ['tran_amount_2014'],ascending=False).head(10)
Top_10_customers_tranx_2014_2015[['customer_id_2015','tran_amount_2015']]=df[['customer_id','tran_amount_2015']].sort_values(by = ['tran_amount_2015'],ascending=False).head(10).reset_index().iloc[:,1:]
Top_10_customers_tranx_2014_2015
# Out:
#   customer_id_2014  tran_amount_2014 customer_id_2015  tran_amount_2015
# 0           CS2945            1029.0           CS4871             538.0
# 1           CS4074            1027.0           CS1157             501.0
# 2           CS4798            1001.0           CS5346             477.0
# 3           CS4424             984.0           CS1802             426.0
# 4           CS5057             974.0           CS5193             410.0
# 5           CS4558             963.0           CS4128             401.0
# 6           CS2647             957.0           CS5049             400.0
# 7           CS4163             949.0           CS3866             398.0
# 8           CS2459             945.0           CS3401             398.0
# 9           CS1141             932.0           CS5016             396.0

# %%
# Describe

df.iloc[:,1:-4].describe().T
# Out:
#                     count        mean         std  min    25%    50%    75%  \
# tran_amount_2011   6889.0  194.562201  133.203153  0.0   93.0  174.0  276.0
# tran_amount_2012   6889.0  307.243286  177.890218  0.0  172.0  284.0  423.0
# tran_amount_2013   6889.0  310.258093  178.065690  0.0  173.0  289.0  429.0
# tran_amount_2014   6889.0  304.036580  173.163978  0.0  171.0  286.0  416.0
# tran_amount_2015   6889.0   63.169546   72.140591  0.0    0.0   49.0   97.0
# transactions_2011  6889.0    2.998694    1.804264  0.0    2.0    3.0    4.0
# transactions_2012  6889.0    4.723617    2.309331  0.0    3.0    5.0    6.0
# transactions_2013  6889.0    4.776310    2.325448  0.0    3.0    5.0    6.0
# transactions_2014  6889.0    4.677892    2.242106  0.0    3.0    4.0    6.0
# transactions_2015  6889.0    0.968355    1.012344  0.0    0.0    1.0    1.0
#
#                       max
# tran_amount_2011    849.0
# tran_amount_2012   1242.0
# tran_amount_2013   1317.0
# ...

# %%
#ASSIGNMENT BEGINNING

# %%
import numpy as np
import pandas as pd

# %%
retail = pd.read_csv(r'file:///C:\Users\grego\Downloads\Retail%20Summary.csv')
retail
# Out:
#      customer_id  tran_amount_2011  tran_amount_2012  tran_amount_2013  \
# 0         CS2945             153.0             516.0             173.0
# 1         CS4074             269.0             429.0             737.0
# 2         CS4798             153.0             536.0             414.0
# 3         CS4424             547.0             380.0             921.0
# 4         CS5057             290.0             235.0             509.0
# ...          ...               ...               ...               ...
# 6884      CS8633             143.0             168.0             122.0
# 6885      CS8667              44.0             178.0              85.0
# 6886      CS8740              55.0             218.0              17.0
# 6887      CS8753             126.0             289.0              82.0
# 6888      CS8760             106.0              71.0              59.0
#
#       tran_amount_2014  tran_amount_2015  transactions_2011  \
# ...

# %%
retail.tail()
# Out:
#      customer_id  tran_amount_2011  tran_amount_2012  tran_amount_2013  \
# 6884      CS8633             143.0             168.0             122.0
# 6885      CS8667              44.0             178.0              85.0
# 6886      CS8740              55.0             218.0              17.0
# 6887      CS8753             126.0             289.0              82.0
# 6888      CS8760             106.0              71.0              59.0
#
#       tran_amount_2014  tran_amount_2015  transactions_2011  \
# 6884               NaN               NaN                4.0
# 6885               NaN               NaN                1.0
# 6886               NaN               NaN                2.0
# 6887               NaN               NaN                3.0
# 6888               NaN               NaN                2.0
#
#       transactions_2012  transactions_2013  transactions_2014  \
# 6884                4.0                4.0                NaN
# ...

# %%
# shape & size of the dataset
# print(df.shape)
print(retail.shape)
print(retail.size)
# Out:
# (6889, 13)
# 89557

# %%
retail.isna().sum()
# Out:
# customer_id              0
# tran_amount_2011       388
# tran_amount_2012        80
# tran_amount_2013        85
# tran_amount_2014        88
# tran_amount_2015      2664
# transactions_2011      388
# transactions_2012       80
# transactions_2013       85
# transactions_2014       88
# transactions_2015     2664
# First_Transaction        0
# Latest_Transaction       0
# dtype: int64

# %%
retail.fillna(0, inplace=True)

# %%
retail.head()
# Out:
#   customer_id  tran_amount_2011  tran_amount_2012  tran_amount_2013  \
# 0      CS2945             153.0             516.0             173.0
# 1      CS4074             269.0             429.0             737.0
# 2      CS4798             153.0             536.0             414.0
# 3      CS4424             547.0             380.0             921.0
# 4      CS5057             290.0             235.0             509.0
#
#    tran_amount_2014  tran_amount_2015  transactions_2011  transactions_2012  \
# 0            1029.0              40.0                2.0                7.0
# 1            1027.0               0.0                3.0                6.0
# 2            1001.0              47.0                2.0                7.0
# 3             984.0             101.0                7.0                5.0
# 4             974.0               0.0                4.0                4.0
#
#    transactions_2013  transactions_2014  transactions_2015 First_Transaction  \
# ...

# %%
retail['Total Customer Spend'] = retail.iloc[:,1:6].sum(axis=1)
retail['Total Customer Tranx'] = retail.iloc[:,6:-3].sum(axis=1)
retail['Customer ATV'] = np.round(retail['Total Customer Spend'].div(retail['Total Customer Tranx']),2)
retail.head()
# Out:
#   customer_id  tran_amount_2011  tran_amount_2012  tran_amount_2013  \
# 0      CS2945             153.0             516.0             173.0
# 1      CS4074             269.0             429.0             737.0
# 2      CS4798             153.0             536.0             414.0
# 3      CS4424             547.0             380.0             921.0
# 4      CS5057             290.0             235.0             509.0
#
#    tran_amount_2014  tran_amount_2015  transactions_2011  transactions_2012  \
# 0            1029.0              40.0                2.0                7.0
# 1            1027.0               0.0                3.0                6.0
# 2            1001.0              47.0                2.0                7.0
# 3             984.0             101.0                7.0                5.0
# 4             974.0               0.0                4.0                4.0
#
#    transactions_2013  transactions_2014  transactions_2015 First_Transaction  \
# ...

# %%
retail[retail['Total Customer Tranx']==retail['Total Customer Tranx'].max()]
# Out:
#   customer_id  tran_amount_2011  tran_amount_2012  tran_amount_2013  \
# 3      CS4424             547.0             380.0             921.0
#
#    tran_amount_2014  tran_amount_2015  transactions_2011  transactions_2012  \
# 3             984.0             101.0                7.0                5.0
#
#    transactions_2013  transactions_2014  transactions_2015 First_Transaction  \
# 3               13.0               13.0                1.0         25-May-11
#
#   Latest_Transaction  Total Customer Spend  Total Customer Tranx  Customer ATV
# 3          19-Jan-15                2933.0                  39.0         75.21

# %%
Top_10_customers_tranx_2014_2015 = pd.DataFrame()
Top_10_customers_tranx_2014_2015[['customer_id_2014','tran_amount_2014']]= retail[['customer_id','tran_amount_2014']].sort_values(by = ['tran_amount_2014'],ascending=False).head(10)
Top_10_customers_tranx_2014_2015[['customer_id_2015','tran_amount_2015']]=retail[['customer_id','tran_amount_2015']].sort_values(by = ['tran_amount_2015'],ascending=False).head(10).reset_index().iloc[:,1:]
Top_10_customers_tranx_2014_2015
# Out:
#   customer_id_2014  tran_amount_2014 customer_id_2015  tran_amount_2015
# 0           CS2945            1029.0           CS4871             538.0
# 1           CS4074            1027.0           CS1157             501.0
# 2           CS4798            1001.0           CS5346             477.0
# 3           CS4424             984.0           CS1802             426.0
# 4           CS5057             974.0           CS5193             410.0
# 5           CS4558             963.0           CS4128             401.0
# 6           CS2647             957.0           CS5049             400.0
# 7           CS4163             949.0           CS3866             398.0
# 8           CS2459             945.0           CS3401             398.0
# 9           CS1141             932.0           CS5016             396.0

# %%
retail.iloc[:,1:-4].describe().T
# Out:
#                     count        mean         std  min    25%    50%    75%  \
# tran_amount_2011   6889.0  194.562201  133.203153  0.0   93.0  174.0  276.0
# tran_amount_2012   6889.0  307.243286  177.890218  0.0  172.0  284.0  423.0
# tran_amount_2013   6889.0  310.258093  178.065690  0.0  173.0  289.0  429.0
# tran_amount_2014   6889.0  304.036580  173.163978  0.0  171.0  286.0  416.0
# tran_amount_2015   6889.0   63.169546   72.140591  0.0    0.0   49.0   97.0
# transactions_2011  6889.0    2.998694    1.804264  0.0    2.0    3.0    4.0
# transactions_2012  6889.0    4.723617    2.309331  0.0    3.0    5.0    6.0
# transactions_2013  6889.0    4.776310    2.325448  0.0    3.0    5.0    6.0
# transactions_2014  6889.0    4.677892    2.242106  0.0    3.0    4.0    6.0
# transactions_2015  6889.0    0.968355    1.012344  0.0    0.0    1.0    1.0
#
#                       max
# tran_amount_2011    849.0
# tran_amount_2012   1242.0
# tran_amount_2013   1317.0
# ...
